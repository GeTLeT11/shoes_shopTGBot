# %%
import telebot
import random
import webbrowser
from telebot import types


bot = telebot.TeleBot('7533998043:AAG8J8XTDEoS9OKLxmKdIbrF4aAO-W0-4CI');

answers = ['Я не понял, что ты хочешь сказать.', 'Извини, я тебя не понимаю.', 'Я не знаю такой команды.', 'Мой разработчик не говорил, что отвечать в такой ситуации... >_<']

@bot.message_handler(commands= ['start'] )

def welcome(message):
    markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
    all_shoes = types.KeyboardButton('Все товары')
    btn_girlShoes = types.KeyboardButton('Женская обувь')
    btn_manShoes = types.KeyboardButton('Мужская обувь')
    btn_adress = types.KeyboardButton('Адрес')

    markup.row(btn_girlShoes,btn_manShoes)
    markup.row(all_shoes,btn_adress)

    if message.text == '/start':
        bot.send_message(message.chat.id, f'Привет, {message.from_user.first_name}!\nУ меня ты сможешь купить некоторые товары!\nКонтакт моего разработчика: https://t.me/Kalimulin_R', reply_markup=markup)
    else:
        bot.send_message(message.chat.id, 'Перекинул тебя в главном меню! Выбирай!', reply_markup=markup)

# Обработка фото. Если пользователь пришлет фото, то бот отреагирует на него. Можно реализовать свой функционал
# @bot.message_handler(content_types='photo')
# def get_photo(message):
#     bot.send_message(message.chat.id, 'Я не умею искать по фотографии')

#Действия при выбранных командах
@bot.message_handler()
def info(message):
    if message.text == 'Все товары':
        goodChapter(message)
    elif message.text == 'Адрес':
        adressChapter(message)
    elif message.text == '↩️ Назад':
        welcome(message)
    elif message.text == '↩️ Назад в меню':
        welcome(message)
    elif message.text == 'Женская обувь':
        shoes_girl(message)
    elif message.text == 'Мужская обувь':
        shoes_men(message)
    elif message.text == 'Мужские кроссовки PUMA Puma Morphic Athletic':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('💳 Купить')
        btn2 = types.KeyboardButton('↩️ Назад')
        markup.row(btn1,btn2)
        bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/resize_cache/iblock/bc7/500_500_1/q22lqk3fg31noqy0l7igwgry3i0ykecz.jpg')
        bot.send_message(message.chat.id, 'Morphic Athletic — это новая модель в стиле ретро. \nБлагодаря современному спортивному силуэту она идеально вписывается в любой образ. \nВерх изделия изготовлен из двухцветного сетчатого материала и усилен накладками из искусственной кожи.\nРазмер: 45\nСостав: Верх:кожа, текстиль Материал: 68% текстиль, 32% синтетическая кожа', reply_markup=markup)
        bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/muzhskie-krossovki-puma-puma-morphic-athletic-grey-39591902/',reply_markup=markup)
    elif message.text == 'Мужские кроссовки Nike PEGASUS TRAIL 3 GTX ES':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('💳 Купить')
        btn2 = types.KeyboardButton('↩️ Назад')
        markup.row(btn1,btn2)
        bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/resize_cache/iblock/43d/500_500_1/si72jxtozctkva5pch4nol71g0ugx4df.jpg')
        bot.send_message(message.chat.id, 'Представляем кроссовки Nike Pegasus Trail 3 Gore-Tex Cocao Wow. Эти прочные и водонепроницаемые кроссовки от Nike идеально подойдут для всех ваших пеших прогулок. Благодаря технологии Gore-Tex они обеспечивают максимальную защиту от воды и сохраняют ноги сухими. Кроссовки Pegasus Trail 3 обеспечивают превосходный комфорт и воздухопроницаемость, что позволяет с легкостью преодолевать любую местность. Приготовьтесь стильно покорять трассы в этих потрясающих кроссовках от Nike.\nРазмер: 45\nСостав: Материал:текстиль, синтетические материалы, резина', reply_markup=markup)
        bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/muzhskie-krossovki-nike-pegasus-trail-3-gtx-es-multicolor-dr0137-200/',reply_markup=markup)
    elif message.text == 'Мужские кроссовки Asics GEL-KAYANO 31':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('💳 Купить')
        btn2 = types.KeyboardButton('↩️ Назад')
        markup.row(btn1,btn2)
        bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/resize_cache/iblock/4ff/500_500_1/7h0xan1gtgplzm280agokr4qtcr348za.jpg')
        bot.send_message(message.chat.id, 'Универсальные кроссовки с повышенной стабильностью для ежедневных тренировок. Модель сочетает высокую амортизацию, поддержку и комфорт на длительных дистанциях.\nРазмер: 48, 50, 52, 54\nСостав: верх - текстиль Материал:100% текстиль', reply_markup=markup)
        bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/muzhskie-krossovki-asics-gel-kayano-31-blue-1011b867-401/',reply_markup=markup)
    elif message.text == 'Мужские кеды Street Beat Terra Storm':
            markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
            btn1 = types.KeyboardButton('💳 Купить')
            btn2 = types.KeyboardButton('↩️ Назад')
            markup.row(btn1,btn2)
            bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/iblock/38d/cytp7k5ehkkym4g7upp2e5hs1b96dr80.jpg')
            bot.send_message(message.chat.id, 'Кроссовки Terra Storm от Street Beat — модель для создания стильного образа в прохладное межсезонье. Верх пары выполнен из искусственной кожи. Носок перфорирован для улучшенной вентиляции. Контрастная межподошва из термопластичной резины эффективно гасит вибрации при ходьбе, а подметка с оригинальным рисунком протектора обеспечивает сцепление даже на мокрой поверхности.\nРазмер: 54\nСостав: верх - искусственная кожа, материал 100% искусственная кожа', reply_markup=markup)
            bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/muzhskie-kedy-street-beat-terra-storm-brown-snkm10008-220/',reply_markup=markup)
    elif message.text == 'Женские кроссовки PUMA Voyage Nitro 3 Wns':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('💳 Купить')
        btn2 = types.KeyboardButton('↩️ Назад')
        markup.row(btn1,btn2)
        bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/iblock/134/6sre92vik6rva0ob9yr8wrfmudye37u6.jpg')
        bot.send_message(message.chat.id, 'В прочных кроссовках Voyage NITRO 3 вам не страшно никакое бездорожье. Эта обновленная версия кроссовок для бега оснащена полноразмерной промежуточной подошвой из пеноматериала NITRO, чтобы сделать их легче и обеспечить большую отзывчивость при преодолении дистанций. Наша резиновая подошва PUMAGRIP ATR была переосмыслена и дополнена технологией PWRADAPT, позволяющей шипам свободно двигаться вместе с грунтом. В результате обеспечивается превосходное сцепление с любой поверхностью. Новый, расширенный верх усилен PWRTAPE для улучшенной поддержки и защиты, а дренажные отверстия на носке не оставляют воде ни единого шанса. Побеждайте на беговой дорожке в любую погоду в кроссовках Voyage NITRO 3.\nРазмер: 36,38,40,42\nСостав: 100% текстиль', reply_markup=markup)
        bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/zhenskie-krossovki-puma-voyage-nitro-3-wns-pink-37774603/',reply_markup=markup)
    elif message.text == 'Женские кроссовки Nike AIR ZOOM PEGASUS 40 PRM':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('💳 Купить')
        btn2 = types.KeyboardButton('↩️ Назад')
        markup.row(btn1,btn2)
        bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/resize_cache/iblock/1be/500_500_1/hb0328tqnftlexq6123mw8qeilsemcr4.jpg')
        bot.send_message(message.chat.id, 'Пружинистый ход для любого бега, знакомое, только для вас ощущение Peg возвращается, чтобы помочь вам достичь ваших целей. Эта версия обладает той же отзывчивостью и нейтральной поддержкой, которые вы любите, но с улучшенным комфортом в чувствительных зонах стопы, таких как свод и пальцы ног. Независимо от того, наматываете ли вы длинные марафонские мили, бегаете на скорость до захода солнца или отправляетесь в спонтанную групповую поездку, это все тот же надежный бегун, на которого можно положиться день за днем, пробежка за пробежкой.\nРазмер: 36,38,40,42\nСостав: 100% текстиль', reply_markup=markup)
        bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/zhenskie-krossovki-nike-air-zoom-pegasus-40-prm-multicolor-dv7890-600/',reply_markup=markup)
    elif message.text == 'Женские кроссовки Nike METCON 9':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('💳 Купить')
        btn2 = types.KeyboardButton('↩️ Назад')
        markup.row(btn1,btn2)
        bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/iblock/8af/ws5brk4v8eeax8dqgf9ds7nwamac2z3k.jpg')
        bot.send_message(message.chat.id, 'Неважно, для чего вы тренируетесь, – кроссовки для тренинга Nike Metcon 9 помогут вам достичь ваших целей. Обновленная конструкция пятки Hyperlift и прорезиненные боковые накладки сделали эту обувь классическим эталоном тренировочной обуви для тех, кто занимается спортом, кросс-тренингом и борьбой, и признана мировыми элитными спортсменами.\nРазмер: 36,38,40,42\nСостав: 100% текстиль', reply_markup=markup)
        bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/zhenskie-krossovki-nike-metcon-9-white-dz2537-104/',reply_markup=markup)
    elif message.text == 'Женские кроссовки Nike ZOOM BELLA 6':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('💳 Купить')
        btn2 = types.KeyboardButton('↩️ Назад')
        markup.row(btn1,btn2)
        bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/resize_cache/iblock/1a8/500_500_1/nnihi1p1dvycwhwkduxzqfgd0vwpg98c.jpg')
        bot.send_message(message.chat.id, 'В этих кроссовках Nike Zoom Bella 6 вы сможете преодолеть все препятствия. Конструкция кроссовок позволяет заниматься разными видами спорта. Амортизация Zoom Air придает чувство упругости и мягкости.\nРазмер: 36,38,40,42\nСостав: 100% текстиль', reply_markup=markup)
        bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/zhenskie-krossovki-nike-zoom-bella-6-beige-dr5720-003/',reply_markup=markup)
    elif message.text == '💳 Купить':
        webbrowser.open('https://t.me/Kalimulin_R')
    else:
        bot.send_message(message.chat.id, answers[random.randint(0, 3)])


#Информация об адресе и информации о магазине, ссылка на каталог
def adressChapter(message):
    bot.send_location(message.chat.id, latitude='53.220256', longitude='50.263399')
    bot.send_message(message.chat.id, 'просп. Кирова, 147, Самара, Россия этаж 3\nКонтакты: +7 (846) 331-71-11\nСтраница магазина: https://amazingred.ru/cat/')

#Функция, отвечающа за раздел женской обуви
def shoes_girl(message):
    markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
    btn1 = types.KeyboardButton('Женские кроссовки PUMA Voyage Nitro 3 Wns')
    btn2 = types.KeyboardButton('Женские кроссовки Nike AIR ZOOM PEGASUS 40 PRM')
    btn3 = types.KeyboardButton('Женские кроссовки Nike METCON 9')
    btn4 = types.KeyboardButton('Женские кроссовки Nike ZOOM BELLA 6')
    markup.row(btn1)
    markup.row(btn2)
    markup.row(btn3)
    markup.row(btn4)
    bot.send_message(message.chat.id, 'Вот все товары, которые сейчас находятся в продаже:',  reply_markup=markup)

#Функция, отвечающа за раздел мужской обуви
def shoes_men(message):
    markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
    btn1 = types.KeyboardButton('Мужские кроссовки PUMA Puma Morphic Athletic')
    btn2 = types.KeyboardButton('Мужские кроссовки Nike PEGASUS TRAIL 3 GTX ES')
    btn3 = types.KeyboardButton('Мужские кроссовки Asics GEL-KAYANO 31')
    btn4 = types.KeyboardButton('Мужские кеды Street Beat Terra Storm')
    markup.row(btn1)
    markup.row(btn2)
    markup.row(btn3)
    markup.row(btn4)
    bot.send_message(message.chat.id, 'Вот все товары, которые сейчас находятся в продаже:',  reply_markup=markup)

def goodChapter(message):
    bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/resize_cache/iblock/bc7/500_500_1/q22lqk3fg31noqy0l7igwgry3i0ykecz.jpg')
    bot.send_message(message.chat.id, 'Morphic Athletic — это новая модель в стиле ретро. \nБлагодаря современному спортивному силуэту она идеально вписывается в любой образ. \nВерх изделия изготовлен из двухцветного сетчатого материала и усилен накладками из искусственной кожи.\nРазмер: 45\nСостав: Верх:кожа, текстиль Материал: 68% текстиль, 32% синтетическая кожа')
    bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/muzhskie-krossovki-puma-puma-morphic-athletic-grey-39591902/')
    bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/resize_cache/iblock/43d/500_500_1/si72jxtozctkva5pch4nol71g0ugx4df.jpg')
    bot.send_message(message.chat.id, 'Представляем кроссовки Nike Pegasus Trail 3 Gore-Tex Cocao Wow. Эти прочные и водонепроницаемые кроссовки от Nike идеально подойдут для всех ваших пеших прогулок. Благодаря технологии Gore-Tex они обеспечивают максимальную защиту от воды и сохраняют ноги сухими. Кроссовки Pegasus Trail 3 обеспечивают превосходный комфорт и воздухопроницаемость, что позволяет с легкостью преодолевать любую местность. Приготовьтесь стильно покорять трассы в этих потрясающих кроссовках от Nike.\nРазмер: 45\nСостав: Материал:текстиль, синтетические материалы, резина')
    bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/muzhskie-krossovki-nike-pegasus-trail-3-gtx-es-multicolor-dr0137-200/')
    bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/resize_cache/iblock/4ff/500_500_1/7h0xan1gtgplzm280agokr4qtcr348za.jpg')
    bot.send_message(message.chat.id, 'Универсальные кроссовки с повышенной стабильностью для ежедневных тренировок. Модель сочетает высокую амортизацию, поддержку и комфорт на длительных дистанциях.\nРазмер: 48, 50, 52, 54\nСостав: верх - текстиль Материал:100% текстиль')
    bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/muzhskie-krossovki-asics-gel-kayano-31-blue-1011b867-401/')
    bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/iblock/38d/cytp7k5ehkkym4g7upp2e5hs1b96dr80.jpg')
    bot.send_message(message.chat.id, 'Кроссовки Terra Storm от Street Beat — модель для создания стильного образа в прохладное межсезонье. Верх пары выполнен из искусственной кожи. Носок перфорирован для улучшенной вентиляции. Контрастная межподошва из термопластичной резины эффективно гасит вибрации при ходьбе, а подметка с оригинальным рисунком протектора обеспечивает сцепление даже на мокрой поверхности.\nРазмер: 54\nСостав: верх - искусственная кожа, материал 100% искусственная кожа')
    bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/muzhskie-kedy-street-beat-terra-storm-brown-snkm10008-220/')
    bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/iblock/134/6sre92vik6rva0ob9yr8wrfmudye37u6.jpg')
    bot.send_message(message.chat.id, 'В прочных кроссовках Voyage NITRO 3 вам не страшно никакое бездорожье. Эта обновленная версия кроссовок для бега оснащена полноразмерной промежуточной подошвой из пеноматериала NITRO, чтобы сделать их легче и обеспечить большую отзывчивость при преодолении дистанций. Наша резиновая подошва PUMAGRIP ATR была переосмыслена и дополнена технологией PWRADAPT, позволяющей шипам свободно двигаться вместе с грунтом. В результате обеспечивается превосходное сцепление с любой поверхностью. Новый, расширенный верх усилен PWRTAPE для улучшенной поддержки и защиты, а дренажные отверстия на носке не оставляют воде ни единого шанса. Побеждайте на беговой дорожке в любую погоду в кроссовках Voyage NITRO 3.\nРазмер: 36,38,40,42\nСостав: 100% текстиль')
    bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/zhenskie-krossovki-puma-voyage-nitro-3-wns-pink-37774603/')
    bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/resize_cache/iblock/1be/500_500_1/hb0328tqnftlexq6123mw8qeilsemcr4.jpg')
    bot.send_message(message.chat.id, 'Пружинистый ход для любого бега, знакомое, только для вас ощущение Peg возвращается, чтобы помочь вам достичь ваших целей. Эта версия обладает той же отзывчивостью и нейтральной поддержкой, которые вы любите, но с улучшенным комфортом в чувствительных зонах стопы, таких как свод и пальцы ног. Независимо от того, наматываете ли вы длинные марафонские мили, бегаете на скорость до захода солнца или отправляетесь в спонтанную групповую поездку, это все тот же надежный бегун, на которого можно положиться день за днем, пробежка за пробежкой.\nРазмер: 36,38,40,42\nСостав: 100% текстиль')
    bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/zhenskie-krossovki-nike-air-zoom-pegasus-40-prm-multicolor-dv7890-600/')
    bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/iblock/8af/ws5brk4v8eeax8dqgf9ds7nwamac2z3k.jpg')
    bot.send_message(message.chat.id, 'Неважно, для чего вы тренируетесь, – кроссовки для тренинга Nike Metcon 9 помогут вам достичь ваших целей. Обновленная конструкция пятки Hyperlift и прорезиненные боковые накладки сделали эту обувь классическим эталоном тренировочной обуви для тех, кто занимается спортом, кросс-тренингом и борьбой, и признана мировыми элитными спортсменами.\nРазмер: 36,38,40,42\nСостав: 100% текстиль')
    bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/zhenskie-krossovki-nike-metcon-9-white-dz2537-104/')
    bot.send_photo(message.chat.id, 'https://amazingred.ru/upload/resize_cache/iblock/1a8/500_500_1/nnihi1p1dvycwhwkduxzqfgd0vwpg98c.jpg')
    bot.send_message(message.chat.id, 'В этих кроссовках Nike Zoom Bella 6 вы сможете преодолеть все препятствия. Конструкция кроссовок позволяет заниматься разными видами спорта. Амортизация Zoom Air придает чувство упругости и мягкости.\nРазмер: 36,38,40,42\nСостав: 100% текстиль')
    bot.send_message(message.chat.id, 'Нажмите "Купить" чтобы связаться с продавцовм.\nСсылка на товар: https://amazingred.ru/d/zhenskie-krossovki-nike-zoom-bella-6-beige-dr5720-003/')

    markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
    all_shoes = types.KeyboardButton('Все товары')
    btn_girlShoes = types.KeyboardButton('Женская обувь')
    btn_manShoes = types.KeyboardButton('Мужская обувь')
    btn_adress = types.KeyboardButton('Адрес')

    markup.row(btn_girlShoes,btn_manShoes)
    markup.row(all_shoes,btn_adress)

# Строчка, чтобы программа не останавливалась
bot.polling(none_stop=True)
